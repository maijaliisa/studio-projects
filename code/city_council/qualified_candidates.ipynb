# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('2qualifiedcanditatescleaned.csv')
df.fillna(0,inplace=True)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 77     False
# 78     False
# 79     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# 102    False
# 103    False
# 104    False
# 105    False
# 106    False
# Name: Candidate Office Sought, Length: 107, dtype: bool

# %%
df_city_council = df[df['Candidate Office Sought'].str.contains('City Council')]
df_city_council
# Out:
#                  Candidate Office Sought   Name to Appear on Ballot     Code  \
# 13                City Council President              Felicia Moore  30318.0
# 14                City Council President                C.T. Martin  30311.0
# 15                City Council President                   Alex Wan  30324.0
# 16  City Council Member, Post 1 At Large        Michael Julian Bond  30314.0
# 17  City Council Member, Post 1 At Large        Courtney D. English  30310.0
# 18  City Council Member, Post 2 At Large          Matt Westmoreland  30309.0
# 19  City Council Member, Post 2 At Large           Bret R. Williams  30306.0
# 20  City Council Member, Post 2 At Large                  Cory Ruth  30324.0
# 21  City Council Member, Post 3 At Large              Andre Dickens  30318.0
# 22       City Council Member, District 1                    Oz Hill  30312.0
# 23       City Council Member, District 1                Bill Powell  30316.0
# ...

# %%
df_4 = df_city_council[df_city_council['Candidate Office Sought'].str.contains('4')]
df_4
# Out:
#             Candidate Office Sought   Name to Appear on Ballot     Code  \
# 36  City Council Member, District 4               Jason Dozier  30310.0
# 37  City Council Member, District 4              Cleta Winslow  30310.0
# 38  City Council Member, District 4            Kimberly Parmer  30312.0
# 39  City Council Member, District 4  DeBorah "Sister" Williams  30310.0
# 40  City Council Member, District 4                  MR Adassa  30310.0
# 41  City Council Member, District 4                  Nick Hess  30311.0
# 42  City Council Member, District 4      Jonathan R. Whitfield  30314.0
# 43  City Council Member, District 4          Christopher Brown  30310.0
# 44  City Council Member, District 4               Shawn Walton  30314.0
# 45  City Council Member, District 4         Elizabeth Whitmore  30314.0
#
#    Precinct Incumbent Gender
# 36      04V         0      M
# 37      04L         X      F
# 38      04L         0      F
# 39      04L         0      F
# ...

# %%
incumbent = df[df['Incumbent'] == 'X']
len(incumbent)
# Out:
# 14

# %%
incumbent
# Out:
#                             Candidate Office Sought Name to Appear on Ballot  \
# 16             City Council Member, Post 1 At Large      Michael Julian Bond
# 21             City Council Member, Post 3 At Large            Andre Dickens
# 25                  City Council Member, District 1              Carla Smith
# 33                  City Council Member, District 3      Ivory Lee Young Jr.
# 37                  City Council Member, District 4            Cleta Winslow
# 47                  City Council Member, District 5  Natalyn Mosby Archibong
# 51                  City Council Member, District 7             Howard Shook
# 75                 City Council Member, District 12            Joyce Sheperd
# 78             oard of Education Member, District 1             Leslie Grant
# 80             oard of Education Member, District 2               Byron Amos
# 87             oard of Education Member, District 4            Nancy Meister
# ...

# %%
## 14 candidates seeking relelection

# %%
at_large = df[df['Candidate Office Sought'].str.contains('At Large')]
at_large

# %%
new_at_large = at_large[at_large['Candidate Office Sought'].str.contains('City Council')]
new_at_large

# %%
## 30314 - Altanta University Center 
## 
##
##
##
##
##
##
##
##

# %%
df['Code'].value_counts()

# %%
df_mayor = df[df['Candidate Office Sought'] == 'Mayor']

# %%
df_mayor['Code'].value_counts()
# Out:
# 30312.0    3
# 30311.0    2
# 30309.0    1
# 30342.0    1
# 30315.0    1
# 30310.0    1
# 30305.0    1
# 30306.0    1
# 30316.0    1
# 30331.0    1
# Name: Code, dtype: int64

# %%
df_mayor
# Out:
#    Candidate Office Sought Name to Appear on Ballot     Code Precinct  \
# 0                    Mayor     Keisha Lance Bottoms  30331.0      11C
# 1                    Mayor       Ceasar C. Mitchell  30310.0      04L
# 2                    Mayor              Kwanza Hall  30312.0      02G
# 3                    Mayor             Mary Norwood  30305.0      08M
# 4                    Mayor            John H. Eaves  30311.0      10I
# 5                    Mayor             Vincent Fort  30311.0      11R
# 6                    Mayor            Cathy Woolard  30316.0     05A2
# 7                    Mayor               Peter Aman  30342.0      07A
# 8                    Mayor       Rohit Ammanamanchi  30312.0      05J
# 9                    Mayor       Glenn S. Wrightson  30315.0      01E
# 10                   Mayor      Michael T. Sterling  30312.0      01E
# 11                   Mayor               Laban King  30309.0      08P
# ...

# %%
df_mayor['Gender'].value_counts()

# %%
df_school = df[df['Candidate Office Sought'].str.contains('Education')]
len(df_school)

# %%
## 30 people are running for a spot on Board of Education

# %%
len(df_school[df_school['Incumbent'] == 'X'])

# %%
## 6 are incumbent positions

# %%
len(df_school[df_school['Gender'] == 'F'])

# %%
## 17 of the 30 are female
