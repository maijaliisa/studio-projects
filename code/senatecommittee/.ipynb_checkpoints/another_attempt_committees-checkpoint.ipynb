# %%
import pandas as pd
from bs4 import BeautifulSoup
import re
import requests

# %% [markdown]
# ## Senate Special Committee on Aging

# %%
r = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Special_Committee_on_Aging')

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
results = soup.find_all('a')[24:41]

# %%
full_list = []
new = results
for name in new:
    name = (name.text + ', Committee on Aging')
    full_list.append(name)

# %% [markdown]
# ## Senate Committee on Agriculture

# %%
r2 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Agriculture,_Nutrition_and_Forestry')

# %%
soup2 = BeautifulSoup(r2.text, 'html.parser')

# %%
agriculture = soup2.find_all('a')[42:63]

# %%
new = agriculture
for name in new:
    name = (name.text + ', Agriculture Nutrition Forestry')
    full_list.append(name)

# %% [markdown]
# ## (#3) Committee on Appropriations

# %%
r3 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Appropriations')

# %%
soup3 = BeautifulSoup(r3.text, 'html.parser')

# %%
appropriations = soup3.find_all('a')[55:86]

# %%
new3 = appropriations
for name in new3:
    name = (name.text + ", Appropriations")
    full_list.append(name)

# %% [markdown]
# ## (#4) Armed Services

# %%
r4 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Armed_Services')

# %%
soup4 = BeautifulSoup(r4.text, 'html.parser')

# %%
armedservices = soup4.find_all('a')[56:84]

# %%
new4 = armedservices
for name in new4:
    name = (name.text + ', Armed Services')
    full_list.append(name)

# %% [markdown]
# ## (#5) Banking, Housing, Urban Affairs

# %%
r5 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Banking,_Housing,_and_Urban_Affairs')

# %%
soup5 = BeautifulSoup(r5.text, 'html.parser')

# %%
banking = soup5.find_all('a')[27:50]

# %%
new5 = banking
for name in new5:
    name = (name.text + ', Banking Housing Urban Affairs')
    full_list.append(name)

# %% [markdown]
# ## (#6) Budget

# %%
r6 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_the_Budget')

# %%
soup6 = BeautifulSoup(r6.text, 'html.parser')

# %%
budget = soup6.find_all('a')[29:54]

# %%
new6 = budget
for name in new6:
    name = (name.text + ', Budget')
    full_list.append(name)

# %% [markdown]
# ## (#7) Commerce

# %%
r7 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Commerce,_Science,_and_Transportation')

# %%
soup7 = BeautifulSoup(r7.text, 'html.parser')

# %%
commerce = soup7.find_all('a')[62:89]

# %%
for name in commerce:
    name = (name.text + ", Commerce Science & Transportation")
    full_list.append(name)

# %% [markdown]
# ## (#8) Energy and Natural Resource

# %%
r8 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Energy_and_Natural_Resources')

# %%
soup8 = BeautifulSoup(r8.text, 'html.parser')

# %%
energy = soup8.find_all('a')[16:41]

# %%
for name in energy:
    name = (name.text + ', Energy & Natural Resources')
    full_list.append(name)

# %% [markdown]
# ## (#9) Ethics

# %%
r9 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Select_Committee_on_Ethics')

# %%
soup9 = BeautifulSoup(r9.text, 'html.parser')

# %%
ethics = soup9.find_all('a')[10:16]

# %%
for name in ethics:
    name = (name.text + ', Ethics')
    full_list.append(name)

# %% [markdown]
# ## (#10) Environment and Public Works

# %%
r10 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Environment_and_Public_Works')

# %%
soup10 = BeautifulSoup(r10.text, 'html.parser')

# %%
enviro = soup10.find_all('a')[18:40]

# %%
for name in enviro:
    name = (name.text + ', Environment and Public Works')
    full_list.append(name)

# %% [markdown]
# ## (#11)  Finance

# %%
r11 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Finance')

# %%
soup11 = BeautifulSoup(r11.text, 'html.parser')

# %%
finance = soup11.find_all('a')[80:106]

# %%
for name in finance:
    name = (name.text + ', Finance')
    full_list.append(name)

# %% [markdown]
# ## (#12) Foreign Relations

# %%
r12 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Foreign_Relations')

# %%
soup12 = BeautifulSoup(r12.text, 'html.parser')

# %%
foreignrelations = soup12.find_all('a')[55:96]

# %%
for name in foreignrelations:
    name = (name.text + ', Foreign Relations')
    full_list.append(name)

# %% [markdown]
# ## (#13) Health

# %%
r13 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Health,_Education,_Labor_and_Pensions')

# %%
soup13 = BeautifulSoup(r13.text, 'html.parser')

# %%
health = soup13.find_all('a')[60:84]

# %%
for name in health:
    name = (name.text + ', Health Education Labor and Pensions')
    full_list.append(name)

# %% [markdown]
# ## (#14) Homeland Security

# %%
r14 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Homeland_Security_and_Governmental_Affairs')

# %%
soup14 = BeautifulSoup(r14.text, 'html.parser')

# %%
homelandsec = soup14.find_all('a')[41:56]

# %%
for name in homelandsec:
    name = (name.text + ', Homeland Security')
    full_list.append(name)

# %% [markdown]
# ## (#15) Indian Affairs

# %%
r15 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Indian_Affairs')

# %%
soup15 = BeautifulSoup(r15.text, 'html.parser')

# %%
indian = soup15.find_all('a')[58:73]

# %%
for name in indian:
    name = (name.text + ', Indian Affairs')
    full_list.append(name)

# %% [markdown]
# ## (#16) Intelligence

# %%
r16 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Select_Committee_on_Intelligence')

# %%
soup16 = BeautifulSoup(r16.text, 'html.parser')

# %%
intel = soup16.find_all('a')[83:100]

# %%
for name in intel:
    name = (name.text + ', Select Committee on Intelligence')
    full_list.append(name)

# %% [markdown]
# ## (#17) International Narcotics Control

# %%
r17 = requests.get('https://en.wikipedia.org/wiki/International_Narcotics_Control_Caucus')

# %%
soup17 = BeautifulSoup(r17.text, 'html.parser')

# %%
narcotics = soup17.find_all('a')[33:45]

# %%
for name in narcotics:
    name = (name.text + ', Senate Narcotics Caucus')
    full_list.append(name)

# %% [markdown]
# ## (#18) Judiciary

# %%
r18 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_the_Judiciary')

# %%
soup18 = BeautifulSoup(r18.text, 'html.parser')

# %%
judiciary = soup18.find_all('a')[65:86]

# %%
for name in judiciary: 
    name = (name.text + ", Judiciary")
    full_list.append(name)

# %% [markdown]
# ## (#19)  Rules and Administration

# %%
r19 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Rules_and_Administration')

# %%
soup19 = BeautifulSoup(r19.text, 'html.parser')

# %%
rules = soup19.find_all('a')[26:46]

# %%
for name in rules:
    name = (name.text + ', Rules and Administration')
    full_list.append(name)

# %% [markdown]
# ## (#20) Small Business

# %%
r20 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Small_Business_and_Entrepreneurship')

# %%
soup20 = BeautifulSoup(r20.text, 'html.parser')

# %%
smallbus = soup20.find_all('a')[31:50]

# %%
for name in smallbus:
    name = (name.text + ', Small Business and Entrepreneurship')
    full_list.append(name)

# %% [markdown]
# ## (#21) Veterans Affairs

# %%
r21 = requests.get('https://en.wikipedia.org/wiki/United_States_Senate_Committee_on_Veterans%27_Affairs')

# %%
soup21 = BeautifulSoup(r21.text, 'html.parser')

# %%
va = soup21.find_all('a')[26:42]

# %%
for name in va:
    name = (name.text + ', VA')
    full_list.append(name)

# %% [markdown]
# ## Making all this into a dataframe

# %%
# https://stackoverflow.com/questions/42593104/convert-list-into-a-pandas-data-frame

# %%
df = pd.DataFrame(full_list)
df.rename(columns={0:'Senators'},inplace=True)
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.rename.html

# %%
## Split columns 
# https://stackoverflow.com/questions/23317342/pandas-dataframe-split-column-into-multiple-columns-right-align-inconsistent-c

# %%
foo = lambda x: pd.Series([i for i in reversed(x.split(','))])
df= df['Senators'].apply(foo)

# %%
df.rename(columns={0:'Committee', 1:"Senator"}, inplace=True)

# %%
df['Senator'].value_counts()
# Out:
# Jim Risch                 6
# Heidi Heitkamp            6
# Sheldon Whitehouse        6
# Chuck Grassley            5
# John Boozman              5
# Thom Tillis               5
# Mark Warner               5
# John Neely Kennedy        5
# Johnny Isakson            5
# Richard Blumenthal        5
# Tom Udall                 5
# Deb Fischer               5
# Mike Crapo                5
# Tim Scott                 5
# Mazie Hirono              5
# edit                      5
# Jerry Moran               5
# Angus King                5
# Bernie Sanders            5
# Dianne Feinstein          5
# John Hoeven               5
# Marco Rubio               5
# Pat Roberts               5
# Chris Coons               5
# Steve Daines              5
# Catherine Cortez Masto    5
# Jon Tester                5
# Mike Enzi                 5
# Mike Rounds               5
# Brian Schatz              5
#                          ..
# Texas                     1
# Georgia                   1
# ...

# %%
df.set_index('Senator', inplace=True)

# %%
len(df)
# https://pandas.pydata.org/pandas-docs/stable/options.html
# Out:
# 451

# %%
pd.set_option("display.max_rows",451)

# %%
df
# Out:
#                                                    Committee
# Senator
# edit                                      Committee on Aging
# Susan Collins                             Committee on Aging
# Orrin Hatch                               Committee on Aging
# Jeff Flake                                Committee on Aging
# Tim Scott                                 Committee on Aging
# Thom Tillis                               Committee on Aging
# Bob Corker                                Committee on Aging
# Richard Burr                              Committee on Aging
# Marco Rubio                               Committee on Aging
# Deb Fischer                               Committee on Aging
# Bob Casey                                 Committee on Aging
# Bill Nelson                               Committee on Aging
# Sheldon Whitehouse                        Committee on Aging
# Kirsten Gillibrand                        Committee on Aging
# ...

# %%
df.drop(['[11]', '[3]', '[2]','[1]', 'Tennessee','Idaho',
        'Florida','Wisconsin','Arizona','Colorado', 'Indiana', 'Wyoming', 'Georgia', 'Ohio',
        'Kentucky', 'Maryland', 'New Jersey', 'New Hampshire', 'Delaware', 'New Mexico', 'Connecticut',
        'Virginia', 'Massachusetts', 'Oregon', '[4]', '[12]', 'Iowa', 'Idaho', 'Texas', 'California',
        'North Dakota', 'Rhode Island' ], inplace=True)

# %%
df.head(2)
# Out:
#                          Committee
# Senator
# edit            Committee on Aging
# Susan Collins   Committee on Aging

# %% [markdown]
# ## Starting to make a network diagram

# %%
full = df.pivot(columns='Committee', values='Committee').astype(bool).astype(int)
full
# Out:
# Committee                Agriculture Nutrition Forestry   Appropriations  \
# Senator
# Al Franken                                            0                0
# Amy Klobuchar                                         1                0
# Angus King                                            0                0
# Ben Cardin                                            0                0
# Ben Sasse                                             0                0
# Bernie Sanders                                        0                0
# Bill Cassidy                                          0                0
# Bill Nelson                                           0                0
# Bob Casey                                             0                0
# Bob Casey Jr.                                         1                0
# Bob Corker                                            0                0
# Bob Menendez                                          0                0
# ...

# %%
#transposing to find patterns
full.T.head(5)
# Out:
# Senator                          Al Franken  Amy Klobuchar  Angus King  \
# Committee
#  Agriculture Nutrition Forestry           0              1           0
#  Appropriations                           0              0           0
#  Armed Services                           0              0           1
#  Banking Housing Urban Affairs            0              0           0
#  Budget                                   0              0           1
#
# Senator                          Ben Cardin  Ben Sasse  Bernie Sanders  \
# Committee
#  Agriculture Nutrition Forestry           0          0               0
#  Appropriations                           0          0               0
#  Armed Services                           0          1               0
#  Banking Housing Urban Affairs            0          1               0
#  Budget                                   0          0               1
#
# Senator                          Bill Cassidy  Bill Nelson  Bob Casey  \
# Committee
# ...

# %% [markdown]
# ## Centrality of Committees

# %%
committees_adj = full.T.dot(full)
committees_adj.head()
# Out:
# Committee                         Agriculture Nutrition Forestry  \
# Committee
#  Agriculture Nutrition Forestry                               21
#  Appropriations                                                6
#  Armed Services                                                5
#  Banking Housing Urban Affairs                                 4
#  Budget                                                        5
#
# Committee                         Appropriations   Armed Services  \
# Committee
#  Agriculture Nutrition Forestry                6                5
#  Appropriations                               31                3
#  Armed Services                                3               27
#  Banking Housing Urban Affairs                 6                8
#  Budget                                        6                5
#
# Committee                         Banking Housing Urban Affairs   Budget  \
# Committee
# ...

# %%
import matplotlib.pyplot as plt
import networkx as nx

plt.figure(figsize=(30,30))

# 1. Create the graph
committees_graph = nx.from_numpy_matrix(committees_adj.values)

renamed = dict(zip(committees_graph.nodes(), committees_adj.columns))
nx.relabel_nodes(committees_graph, renamed, copy=False)

# 2. Create a layout for our nodes 
layout = nx.spring_layout(committees_graph, iterations=25, k=0.25)

# 3. Draw the parts we want
nx.draw_networkx_edges(committees_graph, layout, edge_color='#e1e1e1')
nx.draw_networkx_nodes(committees_graph, layout)
nx.draw_networkx_labels(committees_graph, layout)

# 4. Turn off the axis because I know you don't want it
plt.axis('off')

#Save fig 
#plt.savefig('ConnectedSenators.svg')

# 5. Tell matplotlib to show it
plt.show()

# %% [markdown]
# ## Using the transposition and the dot product to calculate connectedness
# Connectedness for people
# To see how people are connected to people, we'll use this code here...

# %%
senators_adj = full.dot(full.T)
senators_adj.head(2)
# Out:
# Senator        Al Franken  Amy Klobuchar  Angus King  Ben Cardin  Ben Sasse  \
# Senator
# Al Franken              4              1           1           0          1
# Amy Klobuchar           1              4           1           0          1
#
# Senator        Bernie Sanders  Bill Cassidy  Bill Nelson  Bob Casey  \
# Senator
# Al Franken                  2             2            0          0
# Amy Klobuchar               0             0            1          0
#
# Senator        Bob Casey Jr.  ...   Ted Cruz  Thad Cochran  Thom Tillis  \
# Senator                       ...
# Al Franken                 1  ...          1             0            1
# Amy Klobuchar              1  ...          3             2            1
#
# Senator        Tim Kaine  Tim Scott  Todd Young  Tom Carper  Tom Cotton  \
# Senator
# Al Franken             1          1           1           0           0
# Amy Klobuchar          0          0           1           0           0
#
# ...

# %%
# %matplotlib inline 
import seaborn as sns

sns.heatmap(senators_adj, cmap='YlGnBu')

# %%
committees_adj = full.T.dot(full)
committees_adj.head(2)
# Out:
# Committee                         Agriculture Nutrition Forestry  \
# Committee
#  Agriculture Nutrition Forestry                               21
#  Appropriations                                                6
#
# Committee                         Appropriations   Armed Services  \
# Committee
#  Agriculture Nutrition Forestry                6                5
#  Appropriations                               31                3
#
# Committee                         Banking Housing Urban Affairs   Budget  \
# Committee
#  Agriculture Nutrition Forestry                               4        5
#  Appropriations                                               6        6
#
# Committee                         Commerce Science & Transportation  \
# Committee
#  Agriculture Nutrition Forestry                                   2
#  Appropriations                                                   5
#
# Committee                         Committee on Aging  \
# Committee
# ...

# %%
sns.heatmap(committees_adj, cmap='YlGnBu')
plt.savefig('heatmap.svg')

# %% [markdown]
# ## Centrality of Senators

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(30,30))

# 1. Create the graph
senators_graph = nx.from_numpy_matrix(senators_adj.replace(1,0).replace(2,0).values)

renamed = dict(zip(senators_graph.nodes(), senators_adj.columns))
nx.relabel_nodes(senators_graph, renamed, copy=False)

# 2. Create a layout for our nodes 
layout = nx.spring_layout(senators_graph, iterations=20, k=0.05)

# 3. Draw the parts we want
nx.draw_networkx_edges(senators_graph, layout, edge_color='#e1e1e1')
nx.draw_networkx_nodes(senators_graph, layout)
nx.draw_networkx_labels(senators_graph, layout)

# 4. Turn off the axis because I know you don't want it
plt.axis('off')

#Save fig 
plt.savefig('ConnectedSenatorswithmorethan3committees.svg')

# 5. Tell matplotlib to show it
plt.show()

# %% [markdown]
# ## Centrality of Committees

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,20))

# 1. Create the graph
committees_graph = nx.from_numpy_matrix(committees_adj.values)

renamed = dict(zip(committees_graph.nodes(), committees_adj.columns))
nx.relabel_nodes(committees_graph, renamed, copy=False)

# 2. Create a layout for our nodes 
layout = nx.spring_layout(committees_graph, iterations=100, k=0.25)

# 3. Draw the parts we want
nx.draw_networkx_edges(committees_graph, layout, edge_color='#e1e1e1')
nx.draw_networkx_nodes(committees_graph, layout)
nx.draw_networkx_labels(committees_graph, layout)

# 4. Turn off the axis because I know you don't want it
plt.axis('off')

#Save fig 
#plt.savefig('ConnectedSenators.svg')

# 5. Tell matplotlib to show it
plt.show()

# %% [markdown]
# ## Centrality of Senators

# %%
# 1. Build the graph
senators_graph = nx.from_numpy_matrix(senators_adj.values)

# 2. Relabel the nodes with names instead of numbers
renamed = dict(zip(senators_graph.nodes(), senators_adj.columns))
nx.relabel_nodes(senators_graph, renamed, copy=False)

# %%
senators_centrality = nx.closeness_centrality(senators_graph)
senators_centrality
# Out:
# {'Al Franken': 0.7152777777777778,
#  'Amy Klobuchar': 0.7304964539007093,
#  'Angus King': 0.7923076923076923,
#  'Ben Cardin': 0.7103448275862069,
#  'Ben Sasse': 0.6776315789473685,
#  'Bernie Sanders': 0.7686567164179104,
#  'Bill Cassidy': 0.7103448275862069,
#  'Bill Nelson': 0.7686567164179104,
#  'Bob Casey': 0.6094674556213018,
#  'Bob Casey Jr.': 0.6204819277108434,
#  'Bob Corker': 0.7103448275862069,
#  'Bob Menendez': 0.6912751677852349,
#  'Brian Schatz': 0.7803030303030303,
#  'Catherine Cortez Masto': 0.7744360902255639,
#  'Chris Coons': 0.7518248175182481,
#  'Chris Murphy': 0.6959459459459459,
#  'Chris Van Hollen': 0.7006802721088435,
#  'Chuck Grassley': 0.7357142857142858,
#  'Chuck Schumer': 0.5478723404255319,
#  'Claire McCaskill': 0.7006802721088435,
#  'Cory Booker': 0.6518987341772152,
#  'Cory Gardner': 0.7518248175182481,
#  'Dan Sullivan': 0.7054794520547946,
#  'David Perdue': 0.7253521126760564,
#  'Dean Heller': 0.7410071942446043,
# ...

# %%
full.head(1)
# Out:
# Committee    Agriculture Nutrition Forestry   Appropriations   Armed Services  \
# Senator
# Al Franken                                0                0                0
#
# Committee    Banking Housing Urban Affairs   Budget  \
# Senator
# Al Franken                               0        0
#
# Committee    Commerce Science & Transportation   Committee on Aging  \
# Senator
# Al Franken                                   0                    0
#
# Committee    Energy & Natural Resources   Environment and Public Works  \
# Senator
# Al Franken                            1                              0
#
# Committee    Ethics ...    Foreign Relations  \
# Senator             ...
# Al Franken        0 ...                    0
#
# Committee    Health Education Labor and Pensions   Homeland Security  \
# Senator
# Al Franken                                     1                   0
#
# Committee    Indian Affairs   Judiciary   Rules and Administration  \
# Senator
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(full.values)
# Out:
# array([[ 1.        ,  0.25      ,  0.2236068 , ...,  0.        ,
#          0.2236068 ,  0.        ],
#        [ 0.25      ,  1.        ,  0.2236068 , ...,  0.        ,
#          0.4472136 ,  0.2236068 ],
#        [ 0.2236068 ,  0.2236068 ,  1.        , ...,  0.51639778,
#          0.2       ,  0.        ],
#        ...,
#        [ 0.        ,  0.        ,  0.51639778, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.2236068 ,  0.4472136 ,  0.2       , ...,  0.        ,
#          1.        ,  0.2       ],
#        [ 0.        ,  0.2236068 ,  0.        , ...,  0.        ,
#          0.2       ,  1.        ]])

# %%
similarity = cosine_similarity(full.values)
similarity_df = pd.DataFrame(similarity, columns=full.index, index=full.index)
similarity_df
# Out:
# Senator                 Al Franken  Amy Klobuchar  Angus King  Ben Cardin  \
# Senator
# Al Franken                1.000000       0.250000    0.223607    0.000000
# Amy Klobuchar             0.250000       1.000000    0.223607    0.000000
# Angus King                0.223607       0.223607    1.000000    0.000000
# Ben Cardin                0.000000       0.000000    0.000000    1.000000
# Ben Sasse                 0.288675       0.288675    0.258199    0.000000
# Bernie Sanders            0.447214       0.000000    0.400000    0.223607
# Bill Cassidy              0.500000       0.000000    0.223607    0.250000
# Bill Nelson               0.000000       0.250000    0.223607    0.250000
# Bob Casey                 0.000000       0.000000    0.000000    0.353553
# Bob Casey Jr.             0.353553       0.353553    0.000000    0.000000
# Bob Corker                0.000000       0.000000    0.223607    0.250000
# ...

# %%
import seaborn as sns
sns.heatmap(similarity_df)

# %%
eig_centrality = nx.eigenvector_centrality(senators_graph)
eig_centrality

# %%
for name in sorted(senators_centrality, key=senators_centrality.get, reverse=True)[:10]:
    print(name, senators_centrality[name])

# %%
for name in sorted(eig_centrality, key=eig_centrality.get, reverse=True)[:10]:
    print(name, eig_centrality[name])

# %% [markdown]
# ## Finding cliques

# %%
list(nx.find_cliques(senators_graph))

# %% [markdown]
# ### Connectedness for clubs
#
# We can also **calculate this for the clubs**. All we need to do is switch around the code a little, and move the `.T` (the transposition) *before* we do the dot product.

# %%
membership_adj = full.T.dot(full)
membership_adj.head()
# Out:
# Committee                         Agriculture Nutrition Forestry  \
# Committee
#  Agriculture Nutrition Forestry                               21
#  Appropriations                                                6
#  Armed Services                                                5
#  Banking Housing Urban Affairs                                 4
#  Budget                                                        5
#
# Committee                         Appropriations   Armed Services  \
# Committee
#  Agriculture Nutrition Forestry                6                5
#  Appropriations                               31                3
#  Armed Services                                3               27
#  Banking Housing Urban Affairs                 6                8
#  Budget                                        6                5
#
# Committee                         Banking Housing Urban Affairs   Budget  \
# Committee
# ...

# %%
import seaborn as sns
sns.heatmap(membership_adj,cmap='YlGnBu')

# %%
import seaborn as sns
sns.heatmap(senators_adj,cmap='YlGnBu')

# %%
adjacency = senators_adj.dot(senators_adj.T)
adjacency
# Out:
# Senator                 Al Franken  Amy Klobuchar  Angus King  Ben Cardin  \
# Senator
# Al Franken                     128             72          91          54
# Amy Klobuchar                   72            142          97          53
# Angus King                      91             97         187          68
# Ben Cardin                      54             53          68         145
# Ben Sasse                       55             70          86          41
# Bernie Sanders                 110             67         130         101
# Bill Cassidy                   104             52          90          84
# Bill Nelson                     61             92         101          90
# Bob Casey                       31             28          34          50
# Bob Casey Jr.                   46             42          35          31
# Bob Corker                      55             49          90          85
# ...

# %%
sns.heatmap(adjacency, cmap='YlGnBu')

# %% [markdown]
# ## Visualizing The Network of Senators

# %%
senators_adj.values

# %%
membership_adj.values

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %matplotlib inline
import networkx as nx

g = nx.from_numpy_matrix(senators_adj.values)
nx.draw(g)

# %%
import matplotlib.pyplot as plt

# 1. Create the graph
g = nx.from_numpy_matrix(senators_adj.values)

# 2. Create a layout for our nodes 
layout = nx.spring_layout(g, iterations=20)

# 3. Draw the parts we want
nx.draw_networkx_edges(g, layout)
nx.draw_networkx_nodes(g, layout)
nx.draw_networkx_labels(g, layout)

# 4. Turn off the axis because I know you don't want it
plt.axis('off')

# 5. Tell matplotlib to show it (kind of optional)
plt.show()

# %%
g = nx.from_numpy_matrix(senators_adj.values)
dict((zip(g.nodes(), senators_adj.columns)))

# %%
g = nx.from_numpy_matrix(senators_adj.values)

# 1.5 Rename our nodes from boring numbers
# copy=False is like inplace=True
renamed = dict(zip(g.nodes(), senators_adj.columns))
print("Renaming nodes with", renamed)
nx.relabel_nodes(g, renamed, copy=False)

# 2. Create a layout for our nodes 
layout = nx.spring_layout(g,iterations=20)

# 3. Draw the parts we want
nx.draw_networkx_edges(g, layout)
nx.draw_networkx_nodes(g, layout)
nx.draw_networkx_labels(g, layout)

# 4. Turn off the axis because I know you don't want it
plt.axis('off')

# 5. Tell matplotlib to show it
plt.show()

# %%
g.edges(data=True)[:5]

# %%
for edge in g.edges(data=True):
    print(edge)
    print("-------")

# %%
for source, target, data in g.edges(data=True):
    print("Source is", source)
    print("Target is", target)
    print("Data is", data)
    print("------------")

# %%
[data['weight'] / 2 for source, target, data in g.edges(data=True)]

# %%
g = nx.from_numpy_matrix(membership_adj.values)
dict((zip(g.nodes(), membership_adj.columns)))

# %%
import matplotlib.pyplot as plt
# 1. Create the graph
g = nx.from_numpy_matrix(membership_adj.values)

# 1.5 Rename our nodes from boring numbers
# copy=False is like inplace=True
renamed = dict(zip(g.nodes(), membership_adj.columns))
print("Renaming nodes with", renamed)
nx.relabel_nodes(g, renamed, copy=False)

# 2. Create a layout for our nodes 
layout = nx.spring_layout(g,iterations=50)

# 3. Draw the parts we want
nx.draw_networkx_edges(g, layout)
nx.draw_networkx_nodes(g, layout)
nx.draw_networkx_labels(g, layout)

# 4. Turn off the axis because I know you don't want it
plt.axis('off')

# 5. Tell matplotlib to show it
plt.show()

# %% [markdown]
# ## NetworkX Graphs from Source-Target DataFrame

# %%
#g = nx.from_pandas_dataframe(df_true, source='Senator', target='Committee') 
#nx.draw(g)

# %%
committee = list(df_true.Committee.unique())
committee

# %%
senators = list(df_true.Senator.unique())
senators

# %%
dict(zip(committee, committee))

# %%
# How many connections does a senator have coming out of it?
#g.degree('David Perdue')

# %%
[g.degree(committee) for committee in committee]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))

# 1. Create the graph
g = nx.from_pandas_dataframe(df_true, source='Committee', target='Senator') 

# 2. Create a layout for our nodes 
layout = nx.spring_layout(g,iterations=50)

# 3. Draw the parts we want
# Edges thin and grey
# People small and grey
# Clubs sized according to their number of connections
# Clubs blue
# Labels for clubs ONLY
# People who are highly connected are a highlighted color

# Go through every club name, ask the graph how many
# connections it has. Multiply that by 80 to get the circle size
committee_size = [g.degree(committee) * 80 for committee in committee]
nx.draw_networkx_nodes(g, 
                       layout, 
                       nodelist=committee, 
                       node_size=committee_size, # a LIST of sizes, based on g.degree
                       node_color='lightblue')

# Draw EVERYONE
nx.draw_networkx_nodes(g, layout, nodelist=senators, node_color='#cccccc', node_size=100)

# Draw POPULAR PEOPLE
popular_senators = [senators for senators in senators if g.degree(senators) > 1]
nx.draw_networkx_nodes(g, layout, nodelist=popular_senators, node_color='orange', node_size=100)

nx.draw_networkx_edges(g, layout, width=1, edge_color="#cccccc")

node_labels = dict(zip(committee, committee))
nx.draw_networkx_labels(g, layout, labels=node_labels)

# 4. Turn off the axis because I know you don't want it
plt.axis('off')

plt.title("Senate Committees")

# 5. Tell matplotlib to show it
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))

# 1. Create the graph
g = nx.from_pandas_dataframe(df_true, source='Senator', target='Committee') 

# 2. Create a layout for our nodes 
layout = nx.spring_layout(g,iterations=50)

# 3. Draw the parts we want
# Edges thin and grey
# People small and grey
# Clubs sized according to their number of connections
# Clubs blue
# Labels for clubs ONLY
# People who are highly connected are a highlighted color

# Go through every club name, ask the graph how many
# connections it has. Multiply that by 80 to get the circle size
club_size = [g.degree(committee) * 80 for committee in committee]
nx.draw_networkx_nodes(g, 
                       layout, 
                       nodelist=committee, 
                       node_size=club_size, # a LIST of sizes, based on g.degree
                       node_color='lightblue')

# Draw EVERYONE
nx.draw_networkx_nodes(g, layout, nodelist=senators, node_color='#cccccc', node_size=100)

# Draw POPULAR PEOPLE
popular_people = [senators for senators in senators if g.degree(senators) > 5]
nx.draw_networkx_nodes(g, layout, nodelist=popular_people, node_color='orange', node_size=100)

nx.draw_networkx_edges(g, layout, width=1, edge_color="#cccccc")

node_labels = dict(zip(committee, committee))
#node_labels = dict(zip(senators, senators))
nx.draw_networkx_labels(g, layout, labels=node_labels)

# 4. Turn off the axis because I know you don't want it
plt.axis('off')

plt.title("Senate 2")

# 5. Tell matplotlib to show it
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))

# 1. Create the graph
g = nx.from_pandas_dataframe(df_true, source='Senator', target='Committee') 

# 2. Create a layout for our nodes 
layout = nx.spring_layout(g,iterations=50)

# 3. Draw the parts we want
nx.draw_networkx_edges(g, layout, edge_color='#AAAAAA')

clubs = [node for node in g.nodes() if node in df_true.Committee.unique()]
size = [g.degree(node) * 80 for node in g.nodes() if node in df_true.Committee.unique()]
nx.draw_networkx_nodes(g, layout, nodelist=committee, node_size=size, node_color='lightblue')

people = [node for node in g.nodes() if node in df_true.Senator.unique()]
nx.draw_networkx_nodes(g, layout, nodelist=senators, node_size=100, node_color='#AAAAAA')

high_degree_people = [node for node in g.nodes() if node in df_true.Senator.unique() and g.degree(node) > 3]
nx.draw_networkx_nodes(g, layout, nodelist=high_degree_people, node_size=100, node_color='#fc8d62')

name_dict = dict(zip(senators, senators))
nx.draw_networkx_labels(g, layout, labels=name_dict)

club_dict = dict(zip(committee, committee))
nx.draw_networkx_labels(g, layout, labels=club_dict)

# 4. Turn off the axis because I know you don't want it
plt.axis('off')

plt.title("The Universe of Senate Committees (more than 3 connections)")

# https://stackoverflow.com/questions/30765455/why-is-my-plt-savefig-is-not-working
plt.savefig('The Universe of Senate Committees with more than 3 Connections.svg')
# 5. Tell matplotlib to show it
plt.show()

# %% [markdown]
# ## Prep for Gephi

# %%
nx.write_gexf(g, 'senateuniverse.gexf')

# %%
# !head -n 10 senateuniverse.gexf

# %% [markdown]
# ## Cosine Similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
df_true['Committee'].value_counts()

# %%
cosine_similarity(df_true.values)

# %%
similarity = cosine_similarity(df_true.values)
similarity_df = pd.DataFrame(similarity, columns=df_true.index, index=df_true.index)
similarity_df

# %%
import seaborn as sns
sns.heatmap(df_true,cmap='YlGnBu')
