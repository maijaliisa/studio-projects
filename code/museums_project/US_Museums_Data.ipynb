# %% [markdown]
# The goal of this project is to map cities with the most museums/preservation areas per capita. While places like New York, DC and Chicago will have the most historical institutions, I'm interested to see if there is a correlation between access to musuems/historical areas and population density.
#
# I am also interested to see if there is a correlation between the types of museums...is access to science/natural history museums equal across the entire United States. Are there areas of the country that don't have access to such places. If so, is it a matter of population density? Are there alternative cultural centers?

# %%
#Where did the dataset come from?

#I found the csv to download on Kaggle.com 

#If I had questions about this dataset, who would I ask?
#https://www.kaggle.com/imls/museum-directory


#Write five questions you could ask the data. A simple way to ask decent questions is comparing a measurement across two subgroups. For example, "how do points scored in basketball in the 1950's compare to the 1990's," "how often do women punch walls vs. men punch walls?"
#1 - What city has the highest revenue-generating museums, zoos, etc.? 
#2 - can I add a column with city populations (requiring another dataset), and then compare per capita? 
#3 - compare the # of museums vs. zoos vs. art museums vs. science musuems etc. in each city 
#4 -

# %%
#This is working through pandas and downloading a fun CSV file of all of the museums in the USA 
import pandas as pd
# %matplotlib inline
import geopandas as gpd
from shapely.geometry import Point

# %%
df = pd.read_csv('museums.csv', error_bad_lines = False)
#df.columns
museums = df[['Museum Name', 'Latitude', 'Longitude', 'City (Administrative Location)', 'State (Administrative Location)', 'Museum Type', 'Income', 'Revenue']]
museums.head()
#all_preservation = museums[museums['Museum Type'].str.contains('HISTORIC PRESERVATION')]

#sci= museums[museums['Museum Type'] =='SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM']

#atl_museums = museums['City (Administrative Location)'].str.contains('ATLANTA')
#museums[atl_museums]
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (9,14,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                          Museum Name  Latitude  Longitude  \
# 0                    ALASKA AVIATION HERITAGE MUSEUM  61.17925 -149.97254
# 1                            ALASKA BOTANICAL GARDEN  61.16890 -149.76708
# 2  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...  60.56149 -151.21598
# 3                ALASKA EDUCATORS HISTORICAL SOCIETY  60.56280 -151.26597
# 4                             ALASKA HERITAGE MUSEUM  61.17925 -149.97254
#
#   City (Administrative Location) State (Administrative Location)  \
# 0                      ANCHORAGE                              AK
# 1                      ANCHORAGE                              AK
# 2                          KENAI                              AK
# ...

# %%
#atl_shape = gpd.read_file('Counties_Atlanta_Region_ShapeFiles')
#ax = atl_shape.plot(color='#D3D3D3', figsize=(20,20))
#atl_museums.plot(ax=ax)

# %%
#points = df.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
#atl_museums = gpd.GeoDataFrame(df, geometry=points)
#atl_museums.crs = {'init': 'epsg:4326'}
#atl_shape.crs = {'init': 'epsg:4326'}
#ax = atl_shape.plot(color='#D3D3D3', figsize=(20,20))
#atl_museums.plot()

# %%
museums['Museum Type'].value_counts()
# Out:
# HISTORIC PRESERVATION                            14861
# GENERAL MUSEUM                                    8699
# ART MUSEUM                                        3241
# HISTORY MUSEUM                                    2284
# ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER     1484
# SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM        1081
# ZOO, AQUARIUM, OR WILDLIFE CONSERVATION            564
# CHILDREN'S MUSEUM                                  512
# NATURAL HISTORY MUSEUM                             346
# Name: Museum Type, dtype: int64

# %%
sci= museums[museums['Museum Type'] =='SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM']
sci
# Out:
#                                              Museum Name  Latitude  Longitude  \
# 2      ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...  60.56149 -151.21598
# 97                               MARIE DRAKE PLANETARIUM  58.36674 -134.61082
# 143                                   THOMAS PLANETARIUM  61.21608 -149.88530
# 148            UAA PLANETARIUM AND VISUALIZATION THEATER  64.81712 -147.87837
# 168                          ALABAMA AGRICULTURAL MUSEUM  31.27931  -85.37361
# 195                ALABAMA MUSEUM OF THE HEALTH SCIENCES  33.50142  -86.80725
# 288                            CHRISTENBERRY PLANETARIUM  33.46435  -86.79540
# 303                         COOKS NATURAL SCIENCE MUSEUM  34.58039  -86.98293
# 335                  ENDOWMENT FOR MCWANE SCIENCE CENTER  33.51539  -86.80816
# 343                                       EXPLORE CENTER  30.67080  -88.10646
# 344                        EXPLOREUM MUSEUM OF DISCOVERY  30.69034  -88.03979
# ...

# %%
history = museums[museums['Museum Type'] == 'HISTORY MUSEUM']
history['State (Administrative Location)'].value_counts()
# Out:
# TX    198
# CA    197
# NY    140
# PA    113
# VA     94
# IL     83
# OH     79
# FL     73
# NC     65
# MI     63
# WA     57
# MA     55
# IN     53
# TN     47
# MD     44
# GA     44
# MO     43
# IA     43
# CO     42
# MN     42
# NJ     42
# WI     41
# AL     40
# OK     38
# OR     35
# LA     34
# KY     34
# KS     34
# SC     30
# MT     29
# AR     28
# AZ     26
# NM     25
# CT     24
# ME     22
# NE     21
# WV     21
# WY     19
# MS     19
# NH     18
# SD     18
# VT     15
# NV     14
# AK     14
# RI     14
# UT     11
# ID     11
# HI     10
# DC     10
# ND      8
# DE      4
# Name: State (Administrative Location), dtype: int64

# %%
sci= museums[museums['Museum Type'] =='SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM']

# %%
preservation = museums[museums['Museum Type'] == 'HISTORIC PRESERVATION']
preservation['State (Administrative Location)'].value_counts()
#test = preservation['City (Administrative Location)'] == 'Atlanta'
#test
# Out:
# NY    1058
# CA     949
# PA     861
# OH     727
# TX     649
# IL     622
# MI     541
# MA     522
# WI     476
# NJ     424
# FL     421
# VA     410
# MO     370
# MN     365
# IA     354
# NC     330
# ME     323
# IN     321
# WA     298
# CT     291
# GA     277
# KS     275
# MD     272
# CO     259
# OR     238
# NH     238
# TN     217
# OK     214
# KY     203
# AL     192
# VT     182
# AZ     176
# NE     163
# ND     157
# SC     154
# LA     128
# WV     121
# AR     120
# ID     106
# MT     105
# MS     104
# SD      96
# NM      95
# RI      91
# AK      72
# DE      64
# NV      57
# WY      50
# HI      48
# DC      40
# UT      35
# Name: State (Administrative Location), dtype: int64

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %%
#plt.figure(figsize=(8,8))
#m = Basemap(width=12000000,height=9000000,projection='lcc',
#            resolution=None,lat_1=45.,lat_2=55,lat_0=50,lon_0=-107.)
#m.shadedrelief()
#plt.show()

# %%
museums['State (Administrative Location)'].value_counts().head(25).plot(kind = 'barh')

# %%
df['Museum Type'].value_counts()
# Out:
# HISTORIC PRESERVATION                            14861
# GENERAL MUSEUM                                    8699
# ART MUSEUM                                        3241
# HISTORY MUSEUM                                    2284
# ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER     1484
# SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM        1081
# ZOO, AQUARIUM, OR WILDLIFE CONSERVATION            564
# CHILDREN'S MUSEUM                                  512
# NATURAL HISTORY MUSEUM                             346
# Name: Museum Type, dtype: int64

# %%
df['Museum Type'].value_counts().plot(kind = 'barh')

# %%
df.shape
# Out:
# (33072, 25)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         Museum ID                                        Museum Name  \
# 0      8400200098                    ALASKA AVIATION HERITAGE MUSEUM
# 1      8400200117                            ALASKA BOTANICAL GARDEN
# 2      8400200153  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3      8400200143                ALASKA EDUCATORS HISTORICAL SOCIETY
# 4      8400200027                             ALASKA HERITAGE MUSEUM
# 5      8400200096                           ALASKA HISTORICAL MUSEUM
# 6      8400200078                               ALASKA JEWISH MUSEUM
# 7      8400200084                      ALASKA LIGHTHOUSE ASSOCIATION
# 8      8400200107       ALASKA MASONIC LIBRARY AND MUSEUM FOUNDATION
# 9      8400200073              ALASKA MINING HALL OF FAME FOUNDATION
# 10     8400200131    ALASKA NATIONAL GUARD HISTORICAL HOLDING-MUSEUM
# 11     8400200123                      ALASKA NATIVE HERITAGE CENTER
# ...

# %%
df['City (Administrative Location)'].value_counts().head(25)
# Out:
# NEW YORK         297
# WASHINGTON       228
# CHICAGO          194
# PHILADELPHIA     182
# LOS ANGELES      162
# PORTLAND         141
# HOUSTON          137
# BALTIMORE        122
# SAN FRANCISCO    119
# SPRINGFIELD      118
# RICHMOND         113
# COLUMBUS         111
# AUSTIN           104
# SEATTLE          103
# DALLAS           102
# SAN DIEGO         97
# BOSTON            95
# DENVER            90
# ATLANTA           90
# BROOKLYN          85
# PITTSBURGH        84
# LEXINGTON         83
# MADISON           83
# CLEVELAND         79
# LOUISVILLE        79
# Name: City (Administrative Location), dtype: int64

# %%
df.groupby('Museum Type')['City (Administrative Location)'].value_counts(dropna = False)
# Out:
# Museum Type                                    City (Administrative Location)
# ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER  WASHINGTON                        17
#                                                CHICAGO                           11
#                                                COLUMBUS                           8
#                                                DALLAS                             8
#                                                PHILADELPHIA                       8
#                                                SEATTLE                            8
#                                                NEW YORK                           7
#                                                BALTIMORE                          6
#                                                BATON ROUGE                        6
#                                                DAVIS                              6
# ...

# %%
#Figure this step out! 
df[df['City (Administrative Location)'] == 'Williamsport']
# Out:
# Empty DataFrame
# Columns: [Museum ID, Museum Name, Legal Name, Alternate Name, Museum Type, Institution Name, Street Address (Administrative Location), City (Administrative Location), State (Administrative Location), Zip Code (Administrative Location), Street Address (Physical Location), City (Physical Location), State (Physical Location), Zip Code (Physical Location), Phone Number, Latitude, Longitude, Locale Code (NCES), County Code (FIPS), State Code (FIPS), Region Code (AAM), Employer ID Number, Tax Period, Income, Revenue]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Museum ID', 'Museum Name', 'Legal Name', 'Alternate Name',
#        'Museum Type', 'Institution Name',
#        'Street Address (Administrative Location)',
#        'City (Administrative Location)', 'State (Administrative Location)',
#        'Zip Code (Administrative Location)',
#        'Street Address (Physical Location)', 'City (Physical Location)',
#        'State (Physical Location)', 'Zip Code (Physical Location)',
#        'Phone Number', 'Latitude', 'Longitude', 'Locale Code (NCES)',
#        'County Code (FIPS)', 'State Code (FIPS)', 'Region Code (AAM)',
#        'Employer ID Number', 'Tax Period', 'Income', 'Revenue'],
#       dtype='object')

# %%
df[['Museum ID', 'Museum Name', 'Museum Type', 'City (Administrative Location)', 'Zip Code (Physical Location)', 'Income', 'Revenue']]
# Out:
#         Museum ID                                        Museum Name  \
# 0      8400200098                    ALASKA AVIATION HERITAGE MUSEUM
# 1      8400200117                            ALASKA BOTANICAL GARDEN
# 2      8400200153  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3      8400200143                ALASKA EDUCATORS HISTORICAL SOCIETY
# 4      8400200027                             ALASKA HERITAGE MUSEUM
# 5      8400200096                           ALASKA HISTORICAL MUSEUM
# 6      8400200078                               ALASKA JEWISH MUSEUM
# 7      8400200084                      ALASKA LIGHTHOUSE ASSOCIATION
# 8      8400200107       ALASKA MASONIC LIBRARY AND MUSEUM FOUNDATION
# 9      8400200073              ALASKA MINING HALL OF FAME FOUNDATION
# 10     8400200131    ALASKA NATIONAL GUARD HISTORICAL HOLDING-MUSEUM
# 11     8400200123                      ALASKA NATIVE HERITAGE CENTER
# 12     8409500006                              ALASKA SEALIFE CENTER
# ...

# %%
df['City (Administrative Location)'].str.contains("^ATL", na=False).value_counts()
# Out:
# False    32970
# True       102
# Name: City (Administrative Location), dtype: int64

# %%
df['City (Administrative Location)'].str.contains("NEW YORK").value_counts()
# Out:
# False    32767
# True       305
# Name: City (Administrative Location), dtype: int64

# %%
df['City (Administrative Location)'].str.contains("THOUSAND OAKS").value_counts()
# Out:
# False    33066
# True         6
# Name: City (Administrative Location), dtype: int64

# %%
df['Zip Code (Physical Location)'].astype(float)
df['Zip Code (Physical Location)'].str.contains(30308, na=False).value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-6c932b96e487> in <module>()
#       1 df['Zip Code (Physical Location)'].astype(float)
# ----> 2 df['Zip Code (Physical Location)'].str.contains(30308, na=False).value_counts()
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3075         if (name in self._internal_names_set or name in self._metadata or
#    3076                 name in self._accessors):
# -> 3077             return object.__getattribute__(self, name)
#    3078         else:
#    3079             if name in self._info_axis:
#
# /usr/local/lib/python3.6/site-packages/pandas/core/base.py in __get__(self, instance, owner)
#     241             # this ensures that Series.str.<method> is well defined
#     242             return self.accessor_cls
# ...
