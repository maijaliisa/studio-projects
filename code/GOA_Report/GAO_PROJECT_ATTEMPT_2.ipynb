# %% [markdown]
# Goal: Be more specific about the scope of your project. Keep it measureable and intentional

# %%
import pandas as pd
# %matplotlib inline

# %%
#STEP ONE - FIND PRIORITY RECOMMENDATIONS BY AREA - PRIORITY_GAO_RECS: https://www.gao.gov/resources/presidential-transition/priority-recommendations?browse=topic_ss#results

# %%
areas = pd.read_csv('PRIORITY_GAO_RECS - open_priorities_by_topic.csv')
areas.sort_values(by='Count',ascending=False)
# Out:
#                                 Open Priorities  Count
# 10                        Government Operations    109
# 18                             National Defense     73
# 11                                  Health Care     69
# 15              Information Security/Technology     62
# 1             Auditing and Financial Management     61
# 16                        International Affairs     47
# 12                            Homeland Security     43
# 17                  Justice and Law Enforcement     42
# 19            Natural Resources and Environment     28
# 25                                     Veterans     24
# 22                                        Space     23
# 23                Tax Policy and Administration     20
# 7                                        Energy     20
# 2                           Budget and Spending     20
# 14                                Human Capital     14
# 5                                     Education     11
# ...

# %%
areas.sort_values(by='Count',ascending=False).head(10).plot(kind='bar',x='Open Priorities', figsize=(15,4),legend=False,title='Open Priority Recommendations By Topic')

# %%
#open priorities by agency

# %%
priorities = pd.read_csv('PRIORITY_GAO_RECS - open_priorities_by_agency.csv')
priorities.sort_values(by='Count',ascending=False).plot(kind='bar',x='Agency', legend=False,figsize=(15,4),title='Open Priority Recommendations By Agency')

# %%
just_security = pd.read_csv('PRIORITY_GAO_RECS - just_security.csv')
just_security
# Out:
#                                            Agency          Date  \
# 0                  Office of Personnel Management   Oct 7, 2016
# 1                         Department of Education  Apr 21, 2016
# 2               Executive Office of the President  Jan 29, 2016
# 3               Executive Office of the President  Jun 30, 2014
# 4                   Nuclear Regulatory Commission   Nov 6, 2013
# 5                           Department of Justice   Apr 4, 2013
# 6   National Aeronautics and Space Administration  May 18, 2016
# 7                  Office of Personnel Management  May 18, 2016
# 8                    Department of Transportation  Mar 24, 2016
# 9                    Department of Transportation  Apr 14, 2015
# 10                     Department of the Treasury  Mar 19, 2015
# 11                General Services Administration  Dec 12, 2014
# 12                 Office of Personnel Management   Aug 8, 2014
# 13                 Office of Personnel Management   Oct 7, 2016
# ...

# %%
just_security['Agency'].value_counts()
# Out:
# Office of Personnel Management                   4
# Department of the Treasury                       4
# Department of Housing and Urban Development      3
# Department of Defense                            3
# Executive Office of the President                3
# Environmental Protection Agency                  3
# Department of Transportation                     2
# National Aeronautics and Space Administration    2
# Department of Energy                             1
# Department of Commerce                           1
# General Services Administration                  1
# Department of Justice                            1
# Department of Education                          1
# Department of Veterans Affairs                   1
# Department of State                              1
# Nuclear Regulatory Commission                    1
# Small Business Administration                    1
# Name: Agency, dtype: int64
