# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mlp
import squarify
import seaborn as sns

# %%
import pylab
from matplotlib.patches import Rectangle

# %%
#CSV created from here: http://www.gao.gov/recommendations?browse=orgdesc_s#results 
df = pd.read_csv('GAORecommendations - ByAgency (1).csv')
df.rename(columns = {'Agency.1': 'Branch'},inplace=True)

# %%
df.sort_values(by='OpenReports',ascending=False)
# Out:
#                                                Agency  OpenReports  \
# 51                              Department of Defense         1061
# 48            Department of Health and Human Services          422
# 46                    Department of Homeland Security          420
# 30                         Department of the Treasury          336
# 27                  Executive Office of the President          228
# 29                           Internal Revenue Service          221
# 32                     Department of Veterans Affairs          212
# 53                          Department of Agriculture          186
# 33                       Department of Transportation          182
# 26                    Office of Management and Budget          180
# 31                         Department of the Interior          165
# 55                                           Congress          164
# 49                               Department of Energy          157
# 34                                Department of State          135
# 52                             Department of Commerce          132
# 38                              Department of Justice          119
# 28                    Environmental Protection Agency          107
# 35                                Department of Labor           94
# 50                            Department of Education           93
# 19                    General Services Administration           77
# 39        Department of Housing and Urban Development           72
# 8                      Social Security Administration           71
# 17                     Office of Personnel Management           65
# 12      National Aeronautics and Space Administration           51
# 6                       Small Business Administration           47
# 10  United States Agency for International Develop...           46
# 21                  Federal Communications Commission           42
# 40        United States Customs and Border Protection           40
# 20                             Federal Reserve System           35
# 14                      Nuclear Regulatory Commission           34
# 42                          United States Coast Guard           32
# 18                                Library of Congress           31
# 1    United States Securities and Exchange Commission           29
# 25            Office of Science and Technology Policy           24
# 45                Federal Emergency Management Agency           20
# 43  United States Citizenship and Immigration Serv...           19
# 44             Transportation Security Administration           16
# 47                              Public Health Service           15
# 54               American Battle Monuments Commission           15
# 13                        National Science Foundation           14
# 37                    Drug Enforcement Administration           13
# 0                        United States Postal Service           11
# 23                     Federal Housing Finance Agency           10
# 11    Office of the Director of National Intelligence           10
# 41  United States Immigration and Customs Enforcement            5
# 22              Federal Deposit Insurance Corporation            5
# 2      Washington Metropolitan Area Transit Authority            5
# 56                           Architect of the Capitol            5
# 24  Federal Laboratory Consortium for Technology T...            4
# 16             Office of National Drug Control Policy            4
# 5                           Railroad Retirement Board            4
# 36                     Office of the Attorney General            3
# 9                          Tennessee Valley Authority            2
# 7                             Smithsonian Institution            2
# 4                Pension Benefit Guaranty Corporation            2
# 15                        Office of Government Ethics            1
# 3                                         Peace Corps            1
#
#                 Branch                    Area
# 51           Executive              Department
# 48           Executive              Department
# 46           Executive              Department
# 30           Executive              Department
# 27           Executive               Executive
# 29           Executive                Treasury
# 32           Executive              Department
# 53           Executive              Department
# 33           Executive              Department
# 26           Executive               Executive
# 31           Executive              Department
# 55         Legislative             Legislative
# 49           Executive              Department
# 34           Executive              Department
# 52           Executive              Department
# 38           Executive              Department
# 28         Independent                Interior
# 35           Executive              Department
# 50           Executive              Department
# 19         Independent        Federal Property
# 39           Executive              Department
# 8          Independent               Retirment
# 17         Independent           Civil Service
# 12         Independent          Energy/Science
# 6          Independent                Monetary
# 10           Executive                   State
# 21         Independent                Commerce
# 40           Executive       Homeland Security
# 20         Independent                Monetary
# 14         Independent          Energy/Science
# 42           Executive       Homeland Security
# 18         Legislative             Legislative
# 1          Independent                Monetary
# 25           Executive               Executive
# 45           Executive       Homeland Security
# 43           Executive       Homeland Security
# 44           Executive       Homeland Security
# 47           Executive   Health/Human Services
# 54         Independent                Interior
# 13         Independent          Energy/Science
# 37           Executive                 Justice
# 0          Independent                  Postal
# 23         Independent                Commerce
# 11         Independent                 Defense
# 41           Executive       Homeland Security
# 22         Independent                Monetary
# 2   tri-jurisdictional           Transporation
# 56         Legislative             Legislative
# 24         Independent  Governement Commission
# 16           Executive               Executive
# 5          Independent               Retirment
# 36           Executive                 Justice
# 9          Independent          Energy/Science
# 7          Independent                  Museum
# 4            Executive                   Labor
# 15         Independent           Civil Service
# 3          Independent              Volunteer

# %%
## https://chrisalbon.com/python/pandas_dropping_column_and_rows.html 
df.drop(df.index[2],inplace=True)

# %%
#Number of total open reports 
df['OpenReports'].sum()
# Out:
# 5491

# %%
g = sns.factorplot(x='Area', 
                   y='OpenReports', 
                   data=df, 
                   col='Area',  # Separate by stage
                   kind='swarm') # Swarmplot

# %%
#Number of open reports under an executive branch agency 
executive_total = df[df['Branch'] == 'Executive']
executive_total['OpenReports'].sum()
# Out:
# 4654

# %%
executive_total = df[df['Branch'] == 'Independent']
executive_total['OpenReports'].sum()
# Out:
# 637

# %%
executive_total = df[df['Branch'] == 'Legislative']
executive_total['OpenReports'].sum()
# Out:
# 200

# %%
#trying different mapping techniques

# %%
df_executive = df[df['Branch'] == 'Executive']

# %%
df_independent = df[df['Branch'] == 'Independent']

# %%
mlp.rc("figure", figsize=(15, 8))
sns.swarmplot(x='Branch', y='OpenReports', data=df_independent,label=True)
plt.ylim(0, 110)
#sns.title('Number of Recommendations Per Agency/Department')

#plt.legend(bbox_to_anchor=(1, 1), loc=2)
# Out:
# (0, 110)

# %%
#By priority agency

# %%
df_priority = pd.read_csv('GAORecommendations - Priority (1).csv')
#df_priority.set_index('Department/Agency',inplace=True)

# %%
df_priority
# Out:
#                                     Department/Agency  Count        place
# 0                              Department of Commerce     22    Executive
# 1                               Department of Defense     75    Executive
# 2                                Department of Energy     13    Executive
# 3             Department of Health and Human Services     49    Executive
# 4                     Department of Homeland Security     21    Executive
# 5         Department of Housing and Urban Development      6    Executive
# 6                               Department of Justice     21    Executive
# 7                      Department of Veterans Affairs     22    Executive
# 8                          Department of the Treasury     38    Executive
# 9                   Executive Office of the President     22    Executive
# 10                    Environmental Protection Agency     17  Independent
# 11      National Aeronautics and Space Administration     19  Independent
# 12                        National Science Foundation      1  Independent
# 13                      Nuclear Regulatory Commission      6  Independent
# 14                     Office of Personnel Management     14  Independent
# 15                      Small Business Administration      8  Independent
# 16                     Social Security Administration      6  Independent
# 17  United States Agency for International Develop...     11    Executive

# %%
mlp.rc("figure", figsize=(8, 8))
sns.swarmplot(x='place', y='Count', data=df_priority,label=True)
plt.ylim(0, 100)
plt.savefig('OpenPriorityItemCount.pdf')

# %%
#mlp.rc("figure", figsize=(15, 8))
#sns.swarmplot(x='place', y='OpenReports', data=df,label=True)
#plt.ylim(0, 1200)

# %%
#mlp.rc("figure", figsize=(15, 8))
#sns.plot(data=df_priority,label=True)
#plt.ylim(0, 100)
#plt.xticks(rotation=-45)

# %%
df_executive = df[df['Branch'] == 'Executive']
df_executive
#.plot(x='Branch', y='OpenReports',kind='bar')
# Out:
#                                                Agency  OpenReports     Branch  \
# 4                Pension Benefit Guaranty Corporation            2  Executive
# 10  United States Agency for International Develop...           46  Executive
# 16             Office of National Drug Control Policy            4  Executive
# 25            Office of Science and Technology Policy           24  Executive
# 26                    Office of Management and Budget          180  Executive
# 27                  Executive Office of the President          228  Executive
# 29                           Internal Revenue Service          221  Executive
# 30                         Department of the Treasury          336  Executive
# 31                         Department of the Interior          165  Executive
# 32                     Department of Veterans Affairs          212  Executive
# 33                       Department of Transportation          182  Executive
# 34                                Department of State          135  Executive
# 35                                Department of Labor           94  Executive
# 36                     Office of the Attorney General            3  Executive
# 37                    Drug Enforcement Administration           13  Executive
# 38                              Department of Justice          119  Executive
# 39        Department of Housing and Urban Development           72  Executive
# 40        United States Customs and Border Protection           40  Executive
# 41  United States Immigration and Customs Enforcement            5  Executive
# 42                          United States Coast Guard           32  Executive
# 43  United States Citizenship and Immigration Serv...           19  Executive
# 44             Transportation Security Administration           16  Executive
# 45                Federal Emergency Management Agency           20  Executive
# 46                    Department of Homeland Security          420  Executive
# 47                              Public Health Service           15  Executive
# 48            Department of Health and Human Services          422  Executive
# 49                               Department of Energy          157  Executive
# 50                            Department of Education           93  Executive
# 51                              Department of Defense         1061  Executive
# 52                             Department of Commerce          132  Executive
# 53                          Department of Agriculture          186  Executive
#
#                      Area
# 4                   Labor
# 10                  State
# 16              Executive
# 25              Executive
# 26              Executive
# 27              Executive
# 29               Treasury
# 30             Department
# 31             Department
# 32             Department
# 33             Department
# 34             Department
# 35             Department
# 36                Justice
# 37                Justice
# 38             Department
# 39             Department
# 40      Homeland Security
# 41      Homeland Security
# 42      Homeland Security
# 43      Homeland Security
# 44      Homeland Security
# 45      Homeland Security
# 46             Department
# 47  Health/Human Services
# 48             Department
# 49             Department
# 50             Department
# 51             Department
# 52             Department
# 53             Department

# %%
#mlp.rc("figure", figsize=(15, 8))
#sns.swarmplot(x='Branch', y='OpenReports', data=df_priority,label=True)
#plt.ylim(0, 1200)

# %%
df_time = pd.read_csv('GAORecommendations - TimeData.csv')
df_2015 = df_time[df_time['Date'].str.contains('2015')]
df_2015['Agency'].value_counts().plot(kind='barh')

# %%
df_2013 = df_time[df_time['Date'].str.contains('2013')]
df_2013['Agency'].value_counts().plot(kind='barh')

# %%
# http://strftime.org/
# https://www.youtube.com/watch?v=e661LwjHtZQ&t=1978s&index=9&list=PLewNEVDy7gq2k1hxAyMWZ6OLjIV9uoE7W 
df_time['Date_True'] = pd.to_datetime(df_time['Date'].astype(str),format='%b %d, %Y')
