# %%
import pandas as pd
import geopandas as gpd
# %matplotlib inline
import numpy as np
import geopandas as gpd

# %%
neighborhoods = gpd.read_file('Counties_Atlanta_Region_ShapeFiles')
neighborhoods.plot(figsize=(10,5), color='#D3D3D3')
#ax.axis('off')

# %%
neighborhoods.crs
# Out:
# {'init': 'epsg:4326'}
