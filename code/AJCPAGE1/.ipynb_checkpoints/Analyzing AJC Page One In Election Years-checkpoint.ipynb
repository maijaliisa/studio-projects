# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df2011 = pd.read_csv('Local News Week 3 - Page1Subjects2011.csv')
df2011.rename(columns={'2011':'Subject'}, inplace=True)
df2011.head()
# Out:
#                               Subject  2011count
# 0                              School        137
# 1          Government Budget/Taxation        104
# 2             Employment/Unemployment         63
# 3  Sub-National/Local Budget/Taxation         61
# 4                           Migration         57

# %%
df2012 = pd.read_csv('Local News Week 3 - Page1Subjects2012.csv')
df2012.rename(columns={'Document Count': '2012count'}, inplace=True)

# %%
merged2012 = pd.merge(df2011,df2012,on='Subject',how='outer')
merged2012.sort_values(by='2012count',ascending=False)
# Out:
#                                                Subject  2011count  2012count
# 28                                   Domestic Politics       11.0      134.0
# 0                                               School      137.0      117.0
# 22                     National/Presidential Elections       14.0       92.0
# 1                           Government Budget/Taxation      104.0       77.0
# 10                                           Elections       27.0       60.0
# 6                                   University/College       52.0       59.0
# 8                                   Crime/Legal Action       31.0       54.0
# 99                                   Regional Politics        NaN       40.0
# 17                                     Judicial Branch       17.0       35.0
# 19                                     Corrected Items       16.0       34.0
# 4                                            Migration       57.0       34.0
# ...

# %%
############################################################################################################################################
######2016 vs. 2015######

# %%
df2015 = pd.read_csv('Local News Week 3 - Page1Subjects2015.csv')
df2015.rename(columns={'2015':'Subject'}, inplace=True)
df2015
# Out:
#                                        Subject  2015count
# 0                             Page-One Stories       1105
# 1                            Domestic Politics        197
# 2                           Crime/Legal Action        176
# 3                            Regional Politics        105
# 4                                       School         97
# 5                          Murder/Manslaughter         75
# 6                                    Education         74
# 7                   Government Budget/Taxation         61
# 8                           University/College         48
# 9                                    Transport         47
# 10                                   Elections         46
# 11                                    Religion         43
# 12                             Judicial Branch         40
# 13             National/Presidential Elections         36
# 14                                   Migration         35
# ...

# %%
df2016 = pd.read_csv('Local News Week 3 - Page1Subjects2016.csv')
df2016.rename(columns={'2016':'Subject'}, inplace=True)
df2016
# Out:
#                                 Subject  2016count
# 0                     Domestic Politics        326
# 1                    Crime/Legal Action        190
# 2       National/Presidential Elections        158
# 3                             Elections        143
# 4                   Murder/Manslaughter        120
# 5                             Education        116
# 6                                School        100
# 7                    University/College         64
# 8                     Regional Politics         63
# 9                              Religion         50
# 10                      Law Enforcement         49
# 11                           Sex Crimes         38
# 12           Government Budget/Taxation         37
# 13   Sub-National/Local Budget/Taxation         29
# 14                          Upper House         26
# 15                            Migration         25
# 16                            Terrorism         24
# ...

# %%
dfnew = pd.merge(df2015,df2016,on='Subject',how='outer')
dfnew.dropna(inplace=True)

# %%
dfnew.sort_values(by='2016count',ascending=False)
# Out:
#                                Subject  2015count  2016count
# 1                    Domestic Politics      197.0      326.0
# 2                   Crime/Legal Action      176.0      190.0
# 13     National/Presidential Elections       36.0      158.0
# 10                           Elections       46.0      143.0
# 5                  Murder/Manslaughter       75.0      120.0
# 6                            Education       74.0      116.0
# 4                               School       97.0      100.0
# 8                   University/College       48.0       64.0
# 3                    Regional Politics      105.0       63.0
# 11                            Religion       43.0       50.0
# 17                     Law Enforcement       29.0       49.0
# 43                          Sex Crimes       10.0       38.0
# 7           Government Budget/Taxation       61.0       37.0
# 15  Sub-National/Local Budget/Taxation       31.0       29.0
# ...
