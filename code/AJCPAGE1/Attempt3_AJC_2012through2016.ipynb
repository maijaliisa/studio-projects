# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('attempt3THISONE.csv')
df.set_index('topics',inplace=True)

# %%
df
# Out:
#                 2012  2013  2014  2015  2016
# topics
# politics         478   716   836   685  1132
# crime            638   672   956  1255  1125
# technology        77    50   143   123   199
# media            177   121   113   109   148
# agriculture       10    50    75    19    40
# healthcare       135   108   114   103    66
# transportation   333   220   157   165   228

# %%
df.loc['politics'].plot(legend=True,figsize=(14,6),title="What's Covered In the AJC")
df.loc['crime'].plot(legend=True)
df.loc['technology'].plot(legend=True)
df.loc['media'].plot(legend=True)
df.loc['agriculture'].plot(legend=True)
df.loc['healthcare'].plot(legend=True)
df.loc['transportation'].plot(legend=True)
#plt.savefig('WhatiscoveredAJC.pdf')

# %%
#Comparing crime data - https://gbi.georgia.gov/crime-statistics

# %%
df_crime = pd.read_csv('crime.csv')
df_crime.set_index('type', inplace=True)

# %%
df_crime.loc['violentcrime'].plot(legend=True, figsize=(16,4))
df.loc['crime'].plot(legend=True,title='Violent Crime Vs. Reporting on Crime')

# %%
df_politics = pd.read_csv('natvsregelections2.csv')
df_politics.rename(columns={'Unnamed:0': 'type'},inplace=True)
df_politics.set_index('Unnamed: 0', inplace=True)

# %%
import numpy as np
import matplotlib.patches as mpatches

# %%
df_politics
# Out:
#                    2012  2014  2016
# Unnamed: 0
# nationalelections   287    60   429
# regionalelections   275   317   420

# %%
df_politics = pd.DataFrame(np.random.rand(2012,2014, 2016), columns=['2012', '2014', '2016'])

# %%
A2 = df_politics.loc['nationalelections'].plot(kind='bar', color='red')
A2

# %%
B2 = df_politics.loc['regionalelections'].plot(kind='bar')
B2

# %%
A = [287,60,429]
B = [275,317,420]

X = range(3)

plt.bar(X, A, color = 'blue')
plt.bar(X, B, color = 'red', bottom = A)
plt.show()
#national politics = Blue
#regional politics = Red

# %%
A = [287,60,429]
B = [275,317,420]
x= [2012,2014,2016]

plt.stackplot[x,A,B]
plt.xlim(2012,2016)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
#trace1 = go.Scatter(
#    x=[287,60,429],
#    y=[2012,2014,2016],
#    fill='tozeroy',
#    mode= 'none'
#)
#trace2 = go.Scatter(
#    x=[275,317,420],
#    y=[2012,2014,2016],
#    fill='tonexty',
#    mode= 'none'
#)

#data = [trace1, trace2]
#py.iplot(data, filename='basic-area-no-bound')

# %%
df_politics

# %%
years = [2012,2014,2016]
A = [287,60,429]
B = [275,317,420]

# %%
#red is national news, blue is regional news on politics 
plt.stackplot(years,A,B,colors=['blue','red'])

plt.xlabel('x')
plt.ylabel('y')
plt.title('Regional vs. National News')
plt.show()
##plt.savefig('RegionalVsNationalNews.pdf')
